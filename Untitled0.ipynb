# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenkadma222-ai/CSharp-Interview-Questions/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.select * from students  where between 75 and 85;
2.select COUNT(*) as studentcount from students where attendence  > 85;
3.select * from students where studentName like 'A%';
4.select top 3* from students order by marks desc;
5.select course max(marks) as highestmarks from students group by course;
